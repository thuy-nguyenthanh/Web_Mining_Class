# %%
import nltk
import re
import os
from nltk.probability import FreqDist
from nltk.corpus import stopwords

nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ADMIN\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ADMIN\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
#Read file text
#path=os.path.dirname(__file__)
f = open(r"textdata.txt", "r", encoding="utf-8")
text=f.read()

# %%
#################################
######## Text Processing ########
#################################
text_pre=text.replace("\n","")  # Remove the newline command
text_pre=text.lower() # Convert text to lowercase
text_pre=re.sub(r'[^\w\s]','',text_pre) # Remove punctuation
text_pre = re.sub("\d+", " ", text_pre) # Remove number
text_pre = re.sub(r"[!@#$[]()]'", "", text_pre) # Remove character: !@#$[]()
stop = stopwords.words('english')   # Remove StopWords
text_pre = " ".join(text_pre for text_pre in text_pre.split() if text_pre not in stop)
text_pre=nltk.word_tokenize(text_pre) # Tokenizing

text_pre
# Out:
# ['introduction',
#  'natural',
#  'language',
#  'processing',
#  'nlp',
#  'one',
#  'hottest',
#  'areas',
#  'artificial',
#  'intelligence',
#  'ai',
#  'thanks',
#  'applications',
#  'like',
#  'text',
#  'generators',
#  'compose',
#  'coherent',
#  'essays',
#  'chatbots',
#  'fool',
#  'people',
#  'thinking',
#  'theyre',
#  'sentient',
#  'texttoimage',
#  'programs',
#  'produce',
#  'photorealistic',
#  'images',
#  'anything',
#  'describe',
#  'recent',
#  'years',
#  'brought',
#  'revolution',
#  'ability',
#  'computers',
#  'understand',
#  'human',
#  'languages',
#  'programming',
#  'languages',
#  'even',
#  'biological',
#  'chemical',
#  'sequences',
#  'dna',
#  'protein',
#  'structures',
#  'resemble',
#  'language',
#  'latest',
#  'ai',
#  'models',
#  'unlocking',
#  'areas',
#  'analyze',
#  'meanings',
#  'input',
#  'text',
#  'generate',
#  'meaningful',
#  'expressive',
#  'output',
#  'natural',
#  'language',
#  'processing',
#  'nlp',
#  'natural',
#  'language',
#  'processing',
#  'nlp',
#  'discipline',
#  'building',
#  'machines',
#  'manipulate',
#  'human',
#  'language',
#  'data',
#  'resembles',
#  'human',
#  'language',
#  'way',
#  'written',
#  'spoken',
#  'organized',
#  'evolved',
#  'computational',
#  'linguistics',
#  'uses',
#  'computer',
#  'science',
#  'understand',
#  'principles',
#  'language',
#  'rather',
#  'developing',
#  'theoretical',
#  'frameworks',
#  'nlp',
#  'engineering',
#  'discipline',
#  'seeks',
#  'build',
#  'technology',
#  'accomplish',
#  'useful',
#  'tasks',
#  'nlp',
#  'divided',
#  'two',
#  'overlapping',
#  'subfields',
#  'natural',
#  'language',
#  'understanding',
#  'nlu',
#  'focuses',
#  'semantic',
#  'analysis',
#  'determining',
#  'intended',
#  'meaning',
#  'text',
#  'natural',
#  'language',
#  'generation',
#  'nlg',
#  'focuses',
#  'text',
#  'generation',
#  'machine',
#  'nlp',
#  'separate',
#  'often',
#  'used',
#  'conjunction',
#  'speech',
#  'recognition',
#  'seeks',
#  'parse',
#  'spoken',
#  'language',
#  'words',
#  'turning',
#  'sound',
#  'text',
#  'vice',
#  'versa',
#  'natural',
#  'language',
#  'processing',
#  'nlp',
#  'matter',
#  'nlp',
#  'integral',
#  'part',
#  'everyday',
#  'life',
#  'becoming',
#  'language',
#  'technology',
#  'applied',
#  'diverse',
#  'fields',
#  'like',
#  'retailing',
#  'instance',
#  'customer',
#  'service',
#  'chatbots',
#  'medicine',
#  'interpreting',
#  'summarizing',
#  'electronic',
#  'health',
#  'records',
#  'conversational',
#  'agents',
#  'amazons',
#  'alexa',
#  'apples',
#  'siri',
#  'utilize',
#  'nlp',
#  'listen',
#  'user',
#  'queries',
#  'find',
#  'answers',
#  'sophisticated',
#  'agents',
#  'gpt',
#  'recently',
#  'opened',
#  'commercial',
#  'applications',
#  'generate',
#  'sophisticated',
#  'prose',
#  'wide',
#  'variety',
#  'topics',
#  'well',
#  'power',
#  'chatbots',
#  'capable',
#  'holding',
#  'coherent',
#  'conversations',
#  'google',
#  'uses',
#  'nlp',
#  'improve',
#  'search',
#  'engine',
#  'results',
#  'social',
#  'networks',
#  'like',
#  'facebook',
#  'use',
#  'detect',
#  'filter',
#  'hate',
#  'speech',
#  'nlp',
#  'growing',
#  'increasingly',
#  'sophisticated',
#  'yet',
#  'much',
#  'work',
#  'remains',
#  'done',
#  'current',
#  'systems',
#  'prone',
#  'bias',
#  'incoherence',
#  'occasionally',
#  'behave',
#  'erratically',
#  'despite',
#  'challenges',
#  'machine',
#  'learning',
#  'engineers',
#  'many',
#  'opportunities',
#  'apply',
#  'nlp',
#  'ways',
#  'ever',
#  'central',
#  'functioning',
#  'society',
#  'natural',
#  'language',
#  'processing',
#  'nlp',
#  'used',
#  'nlp',
#  'used',
#  'wide',
#  'variety',
#  'languagerelated',
#  'tasks',
#  'including',
#  'answering',
#  'questions',
#  'classifying',
#  'text',
#  'variety',
#  'ways',
#  'conversing',
#  'users',
#  'tasks',
#  'solved',
#  'nlp',
#  'sentiment',
#  'analysis',
#  'process',
#  'classifying',
#  'emotional',
#  'intent',
#  'text',
#  'generally',
#  'input',
#  'sentiment',
#  'classification',
#  'model',
#  'piece',
#  'text',
#  'output',
#  'probability',
#  'sentiment',
#  'expressed',
#  'positive',
#  'negative',
#  'neutral',
#  'typically',
#  'probability',
#  'based',
#  'either',
#  'handgenerated',
#  'features',
#  'word',
#  'ngrams',
#  'tfidf',
#  'features',
#  'using',
#  'deep',
#  'learning',
#  'models',
#  'capture',
#  'sequential',
#  'long',
#  'shortterm',
#  'dependencies',
#  'sentiment',
#  'analysis',
#  'used',
#  'classify',
#  'customer',
#  'reviews',
#  'various',
#  'online',
#  'platforms',
#  'well',
#  'niche',
#  'applications',
#  'like',
#  'identifying',
#  'signs',
#  'mental',
#  'illness',
#  'online',
#  'comments',
#  'nlp',
#  'sentiment',
#  'analysis',
#  'illustration',
#  'toxicity',
#  'classification',
#  'branch',
#  'sentiment',
#  'analysis',
#  'aim',
#  'classify',
#  'hostile',
#  'intent',
#  'also',
#  'classify',
#  'particular',
#  'categories',
#  'threats',
#  'insults',
#  'obscenities',
#  'hatred',
#  'towards',
#  'certain',
#  'identities',
#  'input',
#  'model',
#  'text',
#  'output',
#  'generally',
#  'probability',
#  'class',
#  'toxicity',
#  'toxicity',
#  'classification',
#  'models',
#  'used',
#  'moderate',
#  'improve',
#  'online',
#  'conversations',
#  'silencing',
#  'offensive',
#  'comments',
#  'detecting',
#  'hate',
#  'speech',
#  'scanning',
#  'documents',
#  'defamation',
#  'machine',
#  'translation',
#  'automates',
#  'translation',
#  'different',
#  'languages',
#  'input',
#  'model',
#  'text',
#  'specified',
#  'source',
#  'language',
#  'output',
#  'text',
#  'specified',
#  'target',
#  'language',
#  'google',
#  'translate',
#  'perhaps',
#  'famous',
#  'mainstream',
#  'application',
#  'models',
#  'used',
#  'improve',
#  'communication',
#  'people',
#  'socialmedia',
#  'platforms',
#  'facebook',
#  'skype',
#  'effective',
#  'approaches',
#  'machine',
#  'translation',
#  'distinguish',
#  'words',
#  'similar',
#  'meanings',
#  'systems',
#  'also',
#  'perform',
#  'language',
#  'identification',
#  'classifying',
#  'text',
#  'one',
#  'language',
#  'another',
#  'named',
#  'entity',
#  'recognition',
#  'aims',
#  'extract',
#  'entities',
#  'piece',
#  'text',
#  'predefined',
#  'categories',
#  'personal',
#  'names',
#  'organizations',
#  'locations',
#  'quantities',
#  'input',
#  'model',
#  'generally',
#  'text',
#  'output',
#  'various',
#  'named',
#  'entities',
#  'along',
#  'start',
#  'end',
#  'positions',
#  'named',
#  'entity',
#  'recognition',
#  'useful',
#  'applications',
#  'summarizing',
#  'news',
#  'articles',
#  'combating',
#  'disinformation',
#  'example',
#  'named',
#  'entity',
#  'recognition',
#  'model',
#  'could',
#  'provide',
#  'named',
#  'entity',
#  'recognition',
#  'nlp',
#  'spam',
#  'detection',
#  'prevalent',
#  'binary',
#  'classification',
#  'problem',
#  'nlp',
#  'purpose',
#  'classify',
#  'emails',
#  'either',
#  'spam',
#  'spam',
#  'detectors',
#  'take',
#  'input',
#  'email',
#  'text',
#  'along',
#  'various',
#  'subtexts',
#  'like',
#  'title',
#  'senders',
#  'name',
#  'aim',
#  'output',
#  'probability',
#  'mail',
#  'spam',
#  'email',
#  'providers',
#  'like',
#  'gmail',
#  'use',
#  'models',
#  'provide',
#  'better',
#  'user',
#  'experience',
#  'detecting',
#  'unsolicited',
#  'unwanted',
#  'emails',
#  'moving',
#  'designated',
#  'spam',
#  'folder',
#  'grammatical',
#  'error',
#  'correction',
#  'models',
#  'encode',
#  'grammatical',
#  'rules',
#  'correct',
#  'grammar',
#  'within',
#  'text',
#  'viewed',
#  'mainly',
#  'sequencetosequence',
#  'task',
#  'model',
#  'trained',
#  'ungrammatical',
#  'sentence',
#  'input',
#  'correct',
#  'sentence',
#  'output',
#  'online',
#  'grammar',
#  'checkers',
#  'like',
#  'grammarly',
#  'wordprocessing',
#  'systems',
#  'like',
#  'microsoft',
#  'word',
#  'use',
#  'systems',
#  'provide',
#  'better',
#  'writing',
#  'experience',
#  'customers',
#  'schools',
#  'also',
#  'use',
#  'grade',
#  'student',
#  'essays',
#  'topic',
#  'modeling',
#  'unsupervised',
#  'text',
#  'mining',
#  'task',
#  'takes',
#  'corpus',
#  'documents',
#  'discovers',
#  'abstract',
#  'topics',
#  'within',
#  'corpus',
#  'input',
#  'topic',
#  'model',
#  'collection',
#  'documents',
#  'output',
#  'list',
#  'topics',
#  'defines',
#  'words',
#  'topic',
#  'well',
#  'assignment',
#  'proportions',
#  'topic',
#  'document',
#  'latent',
#  'dirichlet',
#  'allocation',
#  'lda',
#  'one',
#  'popular',
#  'topic',
#  'modeling',
#  'techniques',
#  'tries',
#  'view',
#  'document',
#  'collection',
#  'topics',
#  'topic',
#  'collection',
#  'words',
#  'topic',
#  'modeling',
#  'used',
#  'commercially',
#  'help',
#  'lawyers',
#  'find',
#  'evidence',
#  'legal',
#  'documents',
#  'text',
#  'generation',
#  'formally',
#  'known',
#  'natural',
#  'language',
#  'generation',
#  'nlg',
#  'produces',
#  'text',
#  'thats',
#  'similar',
#  'humanwritten',
#  'text',
#  'models',
#  'finetuned',
#  'produce',
#  'text',
#  'different',
#  'genres',
#  'formats',
#  'including',
#  'tweets',
#  'blogs',
#  'even',
#  'computer',
#  'code',
#  'text',
#  'generation',
#  'performed',
#  'using',
#  'markov',
#  'processes',
#  'lstms',
#  'bert',
#  'gpt',
#  'lamda',
#  'approaches',
#  'particularly',
#  'useful',
#  'autocomplete',
#  'chatbots',
#  'autocomplete',
#  'predicts',
#  'word',
#  'comes',
#  'next',
#  'autocomplete',
#  'systems',
#  'varying',
#  'complexity',
#  'used',
#  'chat',
#  'applications',
#  'like',
#  'whatsapp',
#  'google',
#  'uses',
#  'autocomplete',
#  'predict',
#  'search',
#  'queries',
#  'one',
#  'famous',
#  'models',
#  'autocomplete',
#  'gpt',
#  'used',
#  'write',
#  'articles',
#  'song',
#  'lyrics',
#  'much',
#  'chatbots',
#  'automate',
#  'one',
#  'side',
#  'conversation',
#  'human',
#  'conversant',
#  'generally',
#  'supplies',
#  'side',
#  'divided',
#  'following',
#  'two',
#  'categories',
#  'database',
#  'query',
#  'database',
#  'questions',
#  'answers',
#  'would',
#  'like',
#  'user',
#  'query',
#  'using',
#  'natural',
#  'language',
#  'conversation',
#  'generation',
#  'chatbots',
#  'simulate',
#  'dialogue',
#  'human',
#  'partner',
#  'capable',
#  'engaging',
#  'wideranging',
#  'conversations',
#  'highprofile',
#  'example',
#  'googles',
#  'lamda',
#  'provided',
#  'humanlike',
#  'answers',
#  'questions',
#  'one',
#  'developers',
#  'convinced',
#  'feelings',
#  'information',
#  'retrieval',
#  'finds',
#  'documents',
#  'relevant',
#  'query',
#  'problem',
#  'every',
#  'search',
#  'recommendation',
#  'system',
#  'faces',
#  'goal',
#  'answer',
#  'particular',
#  'query',
#  'retrieve',
#  'collection',
#  'documents',
#  'may',
#  'numbered',
#  'millions',
#  'set',
#  'relevant',
#  'query',
#  'document',
#  'retrieval',
#  'systems',
#  'mainly',
#  'execute',
#  'two',
#  'processes',
#  'indexing',
#  'matching',
#  'modern',
#  'systems',
#  'indexing',
#  'done',
#  'vector',
#  'space',
#  'model',
#  'twotower',
#  'networks',
#  'matching',
#  'done',
#  'using',
#  'similarity',
#  'distance',
#  'scores',
#  'google',
#  'recently',
#  'integrated',
#  'search',
#  'function',
#  'multimodal',
#  'information',
#  'retrieval',
#  'model',
#  'works',
#  'text',
#  'image',
#  'video',
#  'data',
#  'information',
#  'retrieval',
#  'illustration',
#  'summarization',
#  'task',
#  'shortening',
#  'text',
#  'highlight',
#  'relevant',
#  'information',
#  'researchers',
#  'salesforce',
#  'developed',
#  'summarizer',
#  'also',
#  'evaluates',
#  'factual',
#  'consistency',
#  'ensure',
#  'output',
#  'accurate',
#  'summarization',
#  'divided',
#  'two',
#  'method',
#  'classes',
#  'extractive',
#  'summarization',
#  'focuses',
#  'extracting',
#  'important',
#  'sentences',
#  'long',
#  'text',
#  'combining',
#  'form',
#  'summary',
#  'typically',
#  'extractive',
#  'summarization',
#  'scores',
#  'sentence',
#  'input',
#  'text',
#  'selects',
#  'several',
#  'sentences',
#  'form',
#  'summary',
#  'abstractive',
#  'summarization',
#  'produces',
#  'summary',
#  'paraphrasing',
#  'similar',
#  'writing',
#  'abstract',
#  'includes',
#  'words',
#  'sentences',
#  'present',
#  'original',
#  'text',
#  'abstractive',
#  'summarization',
#  'usually',
#  'modeled',
#  'sequencetosequence',
#  'task',
#  'input',
#  'longform',
#  'text',
#  'output',
#  'summary',
#  'question',
#  'answering',
#  'deals',
#  'answering',
#  'questions',
#  'posed',
#  'humans',
#  'natural',
#  'language',
#  'one',
#  'notable',
#  'examples',
#  'question',
#  'answering',
#  'watson',
#  'played',
#  'television',
#  'gameshow',
#  'jeopardy',
#  'human',
#  'champions',
#  'substantial',
#  'margins',
#  'generally',
#  'questionanswering',
#  'tasks',
#  'come',
#  'two',
#  'flavors',
#  'multiple',
#  'choice',
#  'multiplechoice',
#  'question',
#  'problem',
#  'composed',
#  'question',
#  'set',
#  'possible',
#  'answers',
#  'learning',
#  'task',
#  'pick',
#  'correct',
#  'answer',
#  'open',
#  'domain',
#  'opendomain',
#  'question',
#  'answering',
#  'model',
#  'provides',
#  'answers',
#  'questions',
#  'natural',
#  'language',
#  'without',
#  'options',
#  'provided',
#  'often',
#  'querying',
#  'large',
#  'number',
#  'texts',
#  'natural',
#  'language',
#  'processing',
#  'nlp',
#  'work',
#  'nlp',
#  'models',
#  'work',
#  'finding',
#  'relationships',
#  'constituent',
#  'parts',
#  'language',
#  'example',
#  'letters',
#  'words',
#  'sentences',
#  'found',
#  'text',
#  'dataset',
#  'nlp',
#  'architectures',
#  'use',
#  'various',
#  'methods',
#  'data',
#  'preprocessing',
#  'feature',
#  'extraction',
#  'modeling',
#  'processes',
#  'data',
#  'preprocessing',
#  'model',
#  'processes',
#  'text',
#  'specific',
#  'task',
#  'text',
#  'often',
#  ...]

# %%
#################################
##### Exploring Text Data #######
#################################
#print("List of Datasets:",text_pre)
print("Number of words: ",len(text_pre))

# Compute the frequency of all words
frequency_dist = FreqDist(word.lower() for word in text_pre)

## show only th top 50 results
print(frequency_dist.most_common(50))
# Out:
# Number of words:  3213
# [('nlp', 64), ('models', 55), ('language', 52), ('text', 48), ('word', 45), ('model', 31), ('words', 29), ('learning', 26), ('like', 24), ('input', 24), ('natural', 23), ('used', 23), ('output', 18), ('many', 17), ('using', 17), ('deep', 17), ('document', 17), ('one', 16), ('data', 16), ('processing', 15), ('classification', 15), ('probability', 15), ('also', 15), ('techniques', 15), ('sentence', 14), ('ai', 13), ('tasks', 13), ('use', 13), ('neural', 13), ('based', 12), ('information', 12), ('libraries', 12), ('features', 11), ('example', 11), ('task', 11), ('topic', 11), ('training', 11), ('google', 10), ('systems', 10), ('languages', 9), ('machine', 9), ('sentiment', 9), ('documents', 9), ('modeling', 9), ('markov', 9), ('hidden', 9), ('applications', 8), ('human', 8), ('two', 8), ('analysis', 8)]

# %%
## Consider words with length greater than 3 and plot
large_words = dict([(k,v) for k,v in frequency_dist.items() if len(k)>3])
frequency_dist = nltk.FreqDist(large_words)
frequency_dist.plot(50,cumulative=False)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %%
## Build a word cloud
# install library
# pip install wordcloud

from wordcloud import WordCloud
wcloud = WordCloud().generate_from_frequencies(frequency_dist)

#plotting the wordcloud
import matplotlib.pyplot as plt
plt.imshow(wcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
